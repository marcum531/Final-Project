# %%
import pandas as pd

# %%
df = pd.read_csv("employment_data.csv")
df = df.fillna(0)
df = df.replace(to_replace = "*",value = "0")
df.head()
# Out:
#             id       State  \
# 0  0400000US01     Alabama
# 1  0400000US02      Alaska
# 2  0400000US04     Arizona
# 3  0400000US05    Arkansas
# 4  0400000US06  California
#
#    2015_estimate_employment_population_16_years_and_over  \
# 0                                            3878471
# 1                                             571393
# 2                                            5393214
# 3                                            2352507
# 4                                           31068647
#
#   2019_to_2015_statistical_significance_employment_population_16_years_and_over  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    2015_estimate_employment_population_16_years_and_over_in_labor_force  \
# ...

# %%
df.to_csv("new_employment.csv", index=False, header=True)
